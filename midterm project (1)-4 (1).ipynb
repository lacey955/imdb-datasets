# %%
import pandas as pd

# %%
ls
# Out:
# 3HWC.yaml
# 3HWC.yaml.1
# 3HWC.yaml.10
# 3HWC.yaml.11
# 3HWC.yaml.12
# 3HWC.yaml.13
# 3HWC.yaml.14
# 3HWC.yaml.15
# 3HWC.yaml.16
# 3HWC.yaml.17
# 3HWC.yaml.18
# 3HWC.yaml.2
# 3HWC.yaml.3
# 3HWC.yaml.4
# 3HWC.yaml.5
# 3HWC.yaml.6
# 3HWC.yaml.7
# 3HWC.yaml.8
# 3HWC.yaml.9
# AnalysisThreads/
# Applications/
# Catalog and limited region flux.ipynb
# Coordinates.ipynb
# Desktop/
# Documents/
# Downloads/
# Healpy projections.ipynb
# Library/
# Movies/
# Music/
# PHY231_Jibek&Lacey&Piper_Ch3.3_3.4-1.ipynb
# PHY231_JibekIbraeva_Reading_Ch3.1_3.2_Monday_1.ipynb
# PHY231_JibekIbraeva_Visualization_Practice-2 (1).ipynb
# PHY231_JibekIbraeva_Visualization_Practice-2.ipynb
# Pictures/
# Public/
# SMC_data/
# Untitled.R
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# Untitleds.R
# Zotero/
# aerie-apps_bin1-9__allsky_1024_i2.5_r0.0_p1.0_fc2Flux_negSigMap.fits.gz
# axion_center_up.fits
# bookstore_sales.csv
# clean catalog.ipynb
# final project_Jibek Ibraeva.R
# genre_sales.png
# intEGregion1201010F.txt
# midterm project (1)-4.ipynb
# midterm project.ipynb
# pfiles/
# ranking vs amount of votes.png
# ranking vs duration.png
# results_with_crew-3.csv
# whole_sky_map.png
# whole_sky_map1.png

# %%
ls
# Out:
# 3HWC.yaml
# 3HWC.yaml.1
# 3HWC.yaml.10
# 3HWC.yaml.11
# 3HWC.yaml.12
# 3HWC.yaml.13
# 3HWC.yaml.14
# 3HWC.yaml.15
# 3HWC.yaml.16
# 3HWC.yaml.17
# 3HWC.yaml.18
# 3HWC.yaml.2
# 3HWC.yaml.3
# 3HWC.yaml.4
# 3HWC.yaml.5
# 3HWC.yaml.6
# 3HWC.yaml.7
# 3HWC.yaml.8
# 3HWC.yaml.9
# AnalysisThreads/
# Applications/
# Catalog and limited region flux.ipynb
# Coordinates.ipynb
# Desktop/
# Documents/
# Downloads/
# Healpy projections.ipynb
# Library/
# Movies/
# Music/
# PHY231_Jibek&Lacey&Piper_Ch3.3_3.4-1.ipynb
# PHY231_JibekIbraeva_Reading_Ch3.1_3.2_Monday_1.ipynb
# PHY231_JibekIbraeva_Visualization_Practice-2 (1).ipynb
# PHY231_JibekIbraeva_Visualization_Practice-2.ipynb
# Pictures/
# Public/
# SMC_data/
# Untitled.R
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# Untitleds.R
# Zotero/
# aerie-apps_bin1-9__allsky_1024_i2.5_r0.0_p1.0_fc2Flux_negSigMap.fits.gz
# axion_center_up.fits
# bookstore_sales.csv
# clean catalog.ipynb
# final project_Jibek Ibraeva.R
# genre_sales.png
# intEGregion1201010F.txt
# midterm project (1)-4.ipynb
# midterm project.ipynb
# pfiles/
# ranking vs amount of votes.png
# ranking vs duration.png
# results_with_crew-3.csv
# whole_sky_map.png
# whole_sky_map1.png

# %%
movies=pd.read_csv('results_with_crew-3.csv')
movies
# Out:
#           tconst                                   primaryTitle  startYear  \
# 0      tt0111161                       The Shawshank Redemption       1994
# 1      tt0068646                                  The Godfather       1972
# 2      tt0468569                                The Dark Knight       2008
# 3      tt0167260  The Lord of the Rings: The Return of the King       2003
# 4      tt0108052                               Schindler's List       1993
# ...          ...                                            ...        ...
# 4995   tt0211465                               Knockaround Guys       2001
# 4996   tt0210234                         Pokémon the Movie 2000       1999
# 4997  tt19838634                                          Ulajh       2024
# 4998   tt4823776         The SpongeBob Movie: Sponge on the Run       2020
# 4999   tt3171832                                           iBoy       2017
#
#       rank  averageRating  numVotes  runtimeMinutes  \
# 0        1            9.3   3158671             142
# 1        2            9.2   2205040             175
# 2        3            9.1   3135597             152
# 3        4            9.0   2145944             201
# 4        5            9.0   1574009             195
# ...    ...            ...       ...             ...
# 4995  4996            6.1     25695              92
# 4996  4997            6.1     25672              99
# 4997  4998            6.0     25570             150
# 4998  4999            5.9     25340              91
# 4999  5000            5.9     25292              90
#
#                              directors  \
# 0                       Frank Darabont
# 1                 Francis Ford Coppola
# 2                    Christopher Nolan
# 3                        Peter Jackson
# 4                     Steven Spielberg
# ...                                ...
# 4995     Brian Koppelman, David Levien
# 4996                   Kunihiko Yuyama
# 4997  Sudhanshu Saria, Veerendra Singh
# 4998                          Tim Hill
# 4999                      Adam Randall
#
#                                                 writers  \
# 0                          Stephen King, Frank Darabont
# 1                      Mario Puzo, Francis Ford Coppola
# 2     Jonathan Nolan, Christopher Nolan, David S. Go...
# 3     J.R.R. Tolkien, Fran Walsh, Philippa Boyens, P...
# 4                      Thomas Keneally, Steven Zaillian
# ...                                                 ...
# 4995                      Brian Koppelman, David Levien
# 4996                      Satoshi Tajiri, Takeshi Shudô
# 4997      Parveez Shaikh, Sudhanshu Saria, Atika Chohan
# 4998  Tim Hill, Jonathan Aibel, Glenn Berger, Stephe...
# 4999  Kevin Brooks, Joe Barton, Mark Denton, Jonny S...
#
#                             genres  \
# 0                            Drama
# 1                     Crime, Drama
# 2             Action, Crime, Drama
# 3        Adventure, Drama, Fantasy
# 4        Biography, Drama, History
# ...                            ...
# 4995        Crime, Drama, Thriller
# 4996  Action, Adventure, Animation
# 4997        Crime, Drama, Thriller
# 4998  Adventure, Animation, Comedy
# 4999         Action, Crime, Sci-Fi
#
#                                                IMDbLink  \
# 0     <a href="https://www.imdb.com/title/tt0111161"...
# 1     <a href="https://www.imdb.com/title/tt0068646"...
# 2     <a href="https://www.imdb.com/title/tt0468569"...
# 3     <a href="https://www.imdb.com/title/tt0167260"...
# 4     <a href="https://www.imdb.com/title/tt0108052"...
# ...                                                 ...
# 4995  <a href="https://www.imdb.com/title/tt0211465"...
# 4996  <a href="https://www.imdb.com/title/tt0210234"...
# 4997  <a href="https://www.imdb.com/title/tt19838634...
# 4998  <a href="https://www.imdb.com/title/tt4823776"...
# 4999  <a href="https://www.imdb.com/title/tt3171832"...
#
#                                         Title_IMDb_Link
# 0     <a href="https://www.imdb.com/title/tt0111161"...
# 1     <a href="https://www.imdb.com/title/tt0068646"...
# 2     <a href="https://www.imdb.com/title/tt0468569"...
# 3     <a href="https://www.imdb.com/title/tt0167260"...
# 4     <a href="https://www.imdb.com/title/tt0108052"...
# ...                                                 ...
# 4995  <a href="https://www.imdb.com/title/tt0211465"...
# 4996  <a href="https://www.imdb.com/title/tt0210234"...
# 4997  <a href="https://www.imdb.com/title/tt19838634...
# 4998  <a href="https://www.imdb.com/title/tt4823776"...
# 4999  <a href="https://www.imdb.com/title/tt3171832"...
#
# [5000 rows x 12 columns]

# %% [markdown]
# **Questions:**
# 1) Is there a connection between how long a movie is and how high it ranks? Do longer movies tend to score better, or is shorter and tighter the way to go?
# 2) What genre shows up the most, and has this changed over the decades? Are certain genres dominating now that weren't popular before?
# 3) Is there a relationship between number of votes (popularity) and rating? Do "popular" movies actually rate higher, or do smaller films sometimes score better?

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
movies['runtimeMinutes']
# Out:
# 0       142
# 1       175
# 2       152
# 3       201
# 4       195
#        ...
# 4995     92
# 4996     99
# 4997    150
# 4998     91
# 4999     90
# Name: runtimeMinutes, Length: 5000, dtype: int64

# %%
print(movies200['averageRating'].min())
print(movies200['averageRating'].max())
# Out:
# 7.9
# 9.3

# %%
print(movies['runtimeMinutes'].min())
print(movies['runtimeMinutes'].max())
# Out:
# 25
# 374

# %%
movies200 = movies[movies['rank']<401].copy()

# %%
plt.scatter(movies200['runtimeMinutes'], movies200['averageRating'], c=movies200['rank'], cmap='autumn', alpha=0.8, s=30) #check the titles and make colors different for the dots
plt.xlabel('Duration of the Movie (minutes)')
plt.ylabel('Average Audience Rating')
plt.colorbar(label="IMDb Ranking(1-400)")
plt.title("Average Rating vs Duration of the movies")
plt.savefig("ranking vs duration.png")
plt.savefig("averageratingvsduration.png", dpi=300, bbox_inches='tight')

plt.show()

# %%
movies200['runtimeMinutes'].hist(bins=20, color='coral')
plt.title("Distribution of Movie Runtime", fontsize=16)
plt.xlabel("Duration(minutes)", fontsize=14)
plt.savefig("Distribution of Movie Runtime.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
movies200['pop_group'] = pd.qcut(movies200['numVotes'], 3, labels=["Low", "Medium", "High"])

sns.boxplot(x='pop_group', y='averageRating', data=movies200)
plt.xlabel("Popularity Group")
plt.ylabel("Average Rating")
plt.title("Ratings by Popularity Level")
plt.show()

# %%
durrat = movies200.groupby('runtimeMinutes')['rank'].sum()          #i grouped revenues by regions and plotted a bar chart using both of them
durrat.plot(kind='bar', color='teal', figsize=(10, 6))
plt.title('Total Revenue by Region (2024)', fontsize=17)
plt.xlabel('Regions where the books were sold', fontsize=15)
plt.ylabel('Revenue', fontsize=15)
plt.xticks(rotation=360)
plt.tight_layout()
plt.show()

# %%
plt.scatter(movies200['numVotes'],movies200['averageRating'], c=movies200['rank'], cmap='autumn', alpha=0.8, s=30) 
plt.xlabel('Number of votes (popularity in millions)')
plt.ylabel('Average Audience Rating')
plt.colorbar(label="IMDb Ranking (1-400)")
plt.title("Average Rating vs Popularity of the Movie (based on votes)")
plt.savefig("Average rating vs amount of votes.png")
plt.show()

# %%
genresoveryears= movies200.groupby('genres')['startYear'].sum()

# %%
plt.plot(movies['genres'], movies['startYear'], color='steelblue')
plt.title('Year vs Popular Genre', fontsize=16)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Year', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
genre_year = (
    movies_exploded
    .groupby(["startYear", "genres"])
    .size()
    .reset_index(name="count")
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 12
#       8 import matplotlib.pyplot as plt
#      10 plt.figure(figsize=(14,6))
# ---> 12 for genre in pivot.columns:
#      13     plt.plot(pivot.index, pivot[genre], label=genre)
#      15 plt.xlabel("Year")
#
# NameError: name 'pivot' is not defined

# %%
movies200['main_genre'] = movies200['genres'].str.split(',').str[0].str.strip()

# %%
genre_year = (
    movies200
    .groupby(['startYear', 'main_genre'])
    .size()
    .reset_index(name='count')
)
genre_pivot = genre_year.pivot(
    index='startYear',
    columns='main_genre',
    values='count'
).fillna(0)

# %%
import matplotlib.pyplot as plt

genre_pivot.plot(figsize=(12,6))
plt.xlabel("Year")
plt.ylabel("Number of Movies")
plt.title("Genre Popularity Over Time")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


movies200['startYear'] = pd.to_numeric(movies200['startYear'], errors='coerce')
movies200 = movies200.dropna(subset=['startYear'])
movies200['startYear'] = movies200['startYear'].astype(int)


movies200['year_5'] = (movies200['startYear'] // 5) * 5


topN = 5
top_genres = movies200['main_genre'].value_counts().head(topN).index
df_top = movies200[movies200['main_genre'].isin(top_genres)]


genre_5yr = (
    df_top
    .groupby(['year_5', 'main_genre'])
    .size()
    .reset_index(name='count')
)


pivot_5yr = genre_5yr.pivot(
    index='year_5',
    columns='main_genre',
    values='count'
).fillna(0)


pivot_5yr.plot(marker='o', figsize=(12,6))
plt.xlabel("Year (Grouped by 5 years)", fontsize=13)
plt.ylabel("Number of Movies", fontsize=13)

plt.title("Top 5 Genres Over Time (5-Year Groups)", fontsize=16)
plt.legend(title="Genre", fontsize=12, title_fontsize=14)
plt.tight_layout()
plt.savefig("Top 5 Genres over time")
plt.show()
